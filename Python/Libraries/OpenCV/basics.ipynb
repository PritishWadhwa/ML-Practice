# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('Pritish.jpg')

# %%
plt.imshow(img)
plt.show()
#image is in BGR

# %%
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newImg)
plt.show()

# %%
#opencv interprets rgb as bgr and viceversa
cv2.imshow('ME', img)
cv2.waitKey(150) #150ms, if set to 0 then infinite
cv2.destroyAllWindows()
